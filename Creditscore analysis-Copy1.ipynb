# %%
#import the Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Creditscore.csv")
dataset
# Out:
#            ID  Customer_ID  Month           Name   Age          SSN  \
# 0        5634         3392      1  Aaron Maashoh  23.0  821000265.0
# 1        5635         3392      2  Aaron Maashoh  23.0  821000265.0
# 2        5636         3392      3  Aaron Maashoh  23.0  821000265.0
# 3        5637         3392      4  Aaron Maashoh  23.0  821000265.0
# 4        5638         3392      5  Aaron Maashoh  23.0  821000265.0
# ...       ...          ...    ...            ...   ...          ...
# 99995  155625        37932      4          Nicks  25.0   78735990.0
# 99996  155626        37932      5          Nicks  25.0   78735990.0
# 99997  155627        37932      6          Nicks  25.0   78735990.0
# 99998  155628        37932      7          Nicks  25.0   78735990.0
# 99999  155629        37932      8          Nicks  25.0   78735990.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# ...

# %%
dataset.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
drop_notrequired = dataset.drop(columns=['ID', 'Customer_ID','Month','SSN'],axis=1)
drop_notrequired
# Out:
#                 Name   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      Aaron Maashoh  23.0  Scientist       19114.12            1824.843333
# 1      Aaron Maashoh  23.0  Scientist       19114.12            1824.843333
# 2      Aaron Maashoh  23.0  Scientist       19114.12            1824.843333
# 3      Aaron Maashoh  23.0  Scientist       19114.12            1824.843333
# 4      Aaron Maashoh  23.0  Scientist       19114.12            1824.843333
# ...              ...   ...        ...            ...                    ...
# 99995          Nicks  25.0   Mechanic       39628.99            3359.415833
# 99996          Nicks  25.0   Mechanic       39628.99            3359.415833
# 99997          Nicks  25.0   Mechanic       39628.99            3359.415833
# 99998          Nicks  25.0   Mechanic       39628.99            3359.415833
# 99999          Nicks  25.0   Mechanic       39628.99            3359.415833
#
# ...

# %%
dataset.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
dataset["Credit_Score"].value_counts()
# Out:
# Credit_Score
# Standard    53174
# Poor        28998
# Good        17828
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
#categorise the credit score by Annual Income
sns.barplot(x="Credit_Score",y="Annual_Income",data=dataset,hue='Credit_Score')
plt.show()

# %%
#categorise the credit score by Num of loan
sns.barplot(x="Credit_Score",y="Num_of_Loan",data=dataset,hue='Credit_Score')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Credit_Score', y='Credit_Utilization_Ratio', data=dataset, ci=None, palette="viridis")
plt.title('Average Credit Score for Outstanding debt')
plt.xlabel('Category')
plt.ylabel('Average Credit Score')
plt.show()
# Out:
# C:\Users\DIKSHA\AppData\Local\Temp\ipykernel_14364\471801108.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Credit_Score', y='Credit_Utilization_Ratio', data=dataset, ci=None, palette="viridis")

# %%
plt.figure(figsize=(10, 6))
sns.catplot(x='Age', y='Credit_Score', hue='Credit_Score', kind='bar', data=dataset, palette="viridis")
plt.title('Categorical the CreditScore by Age')
plt.xlabel('Age')
plt.ylabel('Credit_Score')
plt.show()
# Out:
# C:\Users\DIKSHA\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dataset.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Create a mapping dictionary for credit score categories
credit_score_mapping = {"Good": 2, "Poor": 0, "Standard": 1}

# Apply the mapping to the 'Credit_Score' column
dataset['Credit_Score'] = dataset['Credit_Score'].map(credit_score_mapping)

# %%
indep=dataset[["Age","Annual_Income","Num_Bank_Accounts","Monthly_Inhand_Salary","Num_Credit_Card","Interest_Rate","Num_of_Loan","Num_of_Delayed_Payment","Outstanding_Debt"]]
               
dep=dataset["Credit_Score"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size=1/3, random_state=42)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#predict the xtest 
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80      9718
#            1       0.81      0.79      0.80     17689
#            2       0.75      0.75      0.75      5927
#
#     accuracy                           0.79     33334
#    macro avg       0.78      0.79      0.78     33334
# weighted avg       0.79      0.79      0.79     33334

# %%
print("Credit Score Prediction : ")
Annual_Income = float(input("Annual Income: "))
Salary = float(input("Monthly Inhand Salary: "))
Bank_Accounts = float(input("Number of Bank Accounts: "))
CreditCard= float(input("Number of Credit cards: "))
Intrest_Rate= float(input("Interest rate: "))
Loans= float(input("Number of Loans: "))
DelayedPayments= float(input("Number of delayed payments: "))
debt= float(input("Outstanding Debt: "))
# Out:
# Credit Score Prediction :
